# %%
import mlflow

mlflow.register_model(
    "runs:/d19486266d664b9f85589170f2257d2b/random_forest_model",
    "luffy.phase2.rf_model_for_ecommerce"
    
)
# Out:
# Registered model 'luffy.phase2.rf_model_for_ecommerce' already exists. Creating a new version of this model...
# Created version '1' of model 'luffy.phase2.rf_model_for_ecommerce'.
# <ModelVersion: aliases=[], creation_timestamp=1772117021868, current_stage=None, description='', last_updated_timestamp=1772117027722, name='luffy.phase2.rf_model_for_ecommerce', run_id='d19486266d664b9f85589170f2257d2b', run_link=None, source='dbfs:/databricks/mlflow-tracking/3732190755780808/d19486266d664b9f85589170f2257d2b/artifacts/random_forest_model', status='READY', status_message='', tags={}, user_id='this15anmoldesu@gmail.com', version='1'>
