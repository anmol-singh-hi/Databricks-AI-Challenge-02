# %%
df = spark.read.table("samples.bakehouse.sales_transactions")
display(df.head(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>transactionID</th><th>customerID</th><th>franchiseID</th><th>dateTime</th><th>product</th><th>quantity</th><th>unitPrice</th><th>totalPrice</th><th>paymentMethod</th><th>cardNumber</th></tr></thead><tbody><tr><td>1002961</td><td>2000253</td><td>3000047</td><td>2024-05-14T12:17:01.495Z</td><td>Golden Gate Ginger</td><td>8</td><td>3</td><td>24</td><td>amex</td><td>378154478982993</td></tr><tr><td>1003007</td><td>2000226</td><td>3000047</td><td>2024-05-10T23:10:10.239Z</td><td>Austin Almond Biscotti</td><td>36</td><td>3</td><td>108</td><td>mastercard</td><td>2244626981238094</td></tr><tr><td>1003017</td><td>2000108</td><td>3000047</td><td>2024-05-16T16:34:10.613Z</td><td>Austin Almond Biscotti</td><td>40</td><td>3</td><td>120</td><td>mastercard</td><td>2490570234487424</td></tr><tr><td>1003068</td><td>2000173</td><td>3000047</td><td>2024-05-02T04:31:51.612Z</td><td>Pearly Pies</td><td>28</td><td>3</td><td>84</td><td>amex</td><td>343808569426192</td></tr><tr><td>1003103</td><td>2000075</td><td>3000047</td><td>2024-05-04T23:44:26.902Z</td><td>Pearly Pies</td><td>28</td><td>3</td><td>84</td><td>visa</td><td>4377080942201798</td></tr><tr><td>1003147</td><td>2000295</td><td>3000047</td><td>2024-05-15T16:17:06.259Z</td><td>Austin Almond Biscotti</td><td>32</td><td>3</td><td>96</td><td>amex</td><td>371093774812677</td></tr><tr><td>1003196</td><td>2000237</td><td>3000047</td><td>2024-05-07T11:13:22.469Z</td><td>Tokyo Tidbits</td><td>40</td><td>3</td><td>120</td><td>mastercard</td><td>5538807345848392</td></tr><tr><td>1003329</td><td>2000272</td><td>3000047</td><td>2024-05-06T03:32:16.017Z</td><td>Outback Oatmeal</td><td>28</td><td>3</td><td>84</td><td>visa</td><td>4872480716880043</td></tr><tr><td>1001264</td><td>2000209</td><td>3000047</td><td>2024-05-16T17:32:28.547Z</td><td>Pearly Pies</td><td>28</td><td>3</td><td>84</td><td>mastercard</td><td>5287105980593305</td></tr><tr><td>1001287</td><td>2000120</td><td>3000047</td><td>2024-05-15T08:41:28.406Z</td><td>Austin Almond Biscotti</td><td>40</td><td>3</td><td>120</td><td>amex</td><td>376211012259783</td></tr></tbody></table></div>

# %%
import pyspark.sql.functions as F

df_franchise = df.groupBy("franchiseID").agg(
  F.sum("quantity").alias("total_products"),
  F.mean('totalPrice').alias("avg_price_by_franchise"),
  F.collect_set('product').alias("products_per_franchise")
)

# %% [markdown]
# ## Using explain()

# %%
df_franchise.explain()
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- == Initial Plan ==
#    ColumnarToRow
#    +- PhotonResultStage
#       +- PhotonGroupingAgg(keys=[franchiseID#13567L], functions=[finalmerge_sum(merge sum#13581L) AS sum(quantity)#13575L, finalmerge_avg(merge sum#13584, count#13585L) AS avg(totalPrice)#13576, collect_list(distinct product#13569, 0, 0)])
#          +- PhotonGroupingAgg(keys=[franchiseID#13567L, product#13569], functions=[merge_sum(merge sum#13581L) AS sum#13581L, merge_avg(merge sum#13584, count#13585L) AS (sum#13584, count#13585L)])
#             +- PhotonGroupingAgg(keys=[franchiseID#13567L, product#13569], functions=[partial_sum(quantity#13570L) AS sum#13581L, partial_avg(totalPrice#13572L) AS (sum#13584, count#13585L)])
#                +- PhotonScan parquet samples.bakehouse.sales_transactions[franchiseID#13567L,product#13569,quantity#13570L,totalPrice#13572L] DataFilters: [], DictionaryFilters: [], Format: parquet, Location: PreparedDeltaFileIndex(1 paths)[s3://system-tables-prod-us-east-2-uc-metastore-bucket/metastore/b..., OptionalDataFilters: [], PartitionFilters: [], ReadSchema: struct<franchiseID:bigint,product:string,quantity:bigint,totalPrice:bigint>, RequiredDataFilters: []
#
#
# == Photon Explanation ==
# The query is fully supported by Photon.
# == Optimizer Statistics (table names per statistics state) ==
#   missing = sales_transactions
#   partial =
#   full    =
# Corrective actions: consider running the following command on all tables with missing or partial statistics
#   ANALYZE TABLE <table-name> COMPUTE STATISTICS FOR ALL COLUMNS

# %%
df_franchise.explain(mode = 'formatted')
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan (7)
# +- == Initial Plan ==
#    ColumnarToRow (6)
#    +- PhotonResultStage (5)
#       +- PhotonGroupingAgg (4)
#          +- PhotonGroupingAgg (3)
#             +- PhotonGroupingAgg (2)
#                +- PhotonScan parquet samples.bakehouse.sales_transactions (1)
#
#
# (1) PhotonScan parquet samples.bakehouse.sales_transactions
# Output [4]: [franchiseID#13617L, product#13619, quantity#13620L, totalPrice#13622L]
# Location: PreparedDeltaFileIndex [s3://system-tables-prod-us-east-2-uc-metastore-bucket/metastore/b622f329-0f39-444f-9dbb-5733ba3e2021/tables/e922f6b4-1ca7-495e-b661-a5e73dc5f5d5]
# ReadSchema: struct<franchiseID:bigint,product:string,quantity:bigint,totalPrice:bigint>
#
# (2) PhotonGroupingAgg
# Input [4]: [franchiseID#13617L, product#13619, quantity#13620L, totalPrice#13622L]
# Arguments: [franchiseID#13617L, product#13619], [partial_sum(quantity#13620L) AS sum#13631L, partial_avg(totalPrice#13622L) AS (sum#13634, count#13635L)], [sum(quantity)#13631L, avg(totalPrice)#13634], [franchiseID#13617L, product#13619, sum#13631L, sum#13634, count#13635L], false
#
# (3) PhotonGroupingAgg
# Input [5]: [franchiseID#13617L, product#13619, sum#13631L, sum#13634, count#13635L]
# Arguments: [franchiseID#13617L, product#13619], [merge_sum(merge sum#13631L) AS sum#13631L, merge_avg(merge sum#13634, count#13635L) AS (sum#13634, count#13635L)], [sum(quantity)#13631L, avg(totalPrice)#13634], [franchiseID#13617L, product#13619, sum#13631L, sum#13634, count#13635L], true
#
# (4) PhotonGroupingAgg
# Input [5]: [franchiseID#13617L, product#13619, sum#13631L, sum#13634, count#13635L]
# Arguments: [franchiseID#13617L], [finalmerge_sum(merge sum#13631L) AS sum(quantity)#13625L, finalmerge_avg(merge sum#13634, count#13635L) AS avg(totalPrice)#13626, collect_list(distinct product#13619, 0, 0)], [sum(quantity)#13625L, avg(totalPrice)#13626, collect_list(product)#13627], [franchiseID#13617L, sum(quantity)#13625L AS total_products#13527L, avg(totalPrice)#13626 AS avg_price_by_franchise#13528, collect_list(product)#13627 AS products_per_franchise#13529], true
#
# (5) PhotonResultStage
# Input [4]: [franchiseID#13617L, total_products#13527L, avg_price_by_franchise#13528, products_per_franchise#13529]
#
# (6) ColumnarToRow
# Input [4]: [franchiseID#13617L, total_products#13527L, avg_price_by_franchise#13528, products_per_franchise#13529]
#
# (7) AdaptiveSparkPlan
# Output [4]: [franchiseID#13617L, total_products#13527L, avg_price_by_franchise#13528, products_per_franchise#13529]
# Arguments: isFinalPlan=false
#
#
# == Photon Explanation ==
# The query is fully supported by Photon.
# == Optimizer Statistics (table names per statistics state) ==
#   missing = sales_transactions
#   partial =
#   full    =
# Corrective actions: consider running the following command on all tables with missing or partial statistics
#   ANALYZE TABLE <table-name> COMPUTE STATISTICS FOR ALL COLUMNS

# %% [markdown]
# ## Heavy Query

# %%
df_filtered = df.filter(F.col("franchiseID") == 3000047)

df_filtered.groupBy("franchiseID").agg(
    F.sum("quantity"),
    F.mean("totalPrice")
).explain(True)
# Out:
# == Parsed Logical Plan ==
# 'Aggregate ['franchiseID], ['franchiseID, unresolvedalias('sum('quantity)), unresolvedalias('avg('totalPrice))]
# +- 'Filter '`==`('franchiseID, 3000047)
#    +- 'UnresolvedRelation [samples, bakehouse, sales_transactions], [], false
#
# == Analyzed Logical Plan ==
# franchiseID: bigint, sum(quantity): bigint, avg(totalPrice): double
# Aggregate [franchiseID#13667L], [franchiseID#13667L, sum(quantity#13670L) AS sum(quantity)#13678L, avg(totalPrice#13672L) AS avg(totalPrice)#13679]
# +- Filter (franchiseID#13667L = cast(3000047 as bigint))
#    +- SubqueryAlias samples.bakehouse.sales_transactions
#       +- Relation samples.bakehouse.sales_transactions[transactionID#13665L,customerID#13666L,franchiseID#13667L,dateTime#13668,product#13669,quantity#13670L,unitPrice#13671L,totalPrice#13672L,paymentMethod#13673,cardNumber#13674L] parquet
#
# == Optimized Logical Plan ==
# Aggregate [franchiseID#13667L], [franchiseID#13667L, sum(quantity#13670L) AS sum(quantity)#13678L, avg(totalPrice#13672L) AS avg(totalPrice)#13679]
# +- Project [franchiseID#13667L, quantity#13670L, totalPrice#13672L]
#    +- Filter (isnotnull(franchiseID#13667L) AND (franchiseID#13667L = 3000047))
#       +- Relation samples.bakehouse.sales_transactions[transactionID#13665L,customerID#13666L,franchiseID#13667L,dateTime#13668,product#13669,quantity#13670L,unitPrice#13671L,totalPrice#13672L,paymentMethod#13673,cardNumber#13674L] parquet
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- == Initial Plan ==
#    PhotonResultStage
#    +- PhotonColumnarToRow
#       +- PhotonGroupingAgg(limit=None, keys=[franchiseID#13667L], functions=[sum(quantity#13670L), avg(totalPrice#13672L)], output=[franchiseID#13667L, sum(quantity)#13678L, avg(totalPrice)#13679])
#          +- PhotonScan parquet samples.bakehouse.sales_transactions[franchiseID#13667L,quantity#13670L,totalPrice#13672L] DataFilters: [isnotnull(franchiseID#13667L), (franchiseID#13667L = 3000047)], DictionaryFilters: [(franchiseID#13667L = 3000047)], Format: parquet, Location: PreparedDeltaFileIndex(1 paths)[s3://system-tables-prod-us-east-2-uc-metastore-bucket/metastore/b..., OptionalDataFilters: [], PartitionFilters: [], ReadSchema: struct<franchiseID:bigint,quantity:bigint,totalPrice:bigint>, RequiredDataFilters: [isnotnull(franchiseID#13667L), (franchiseID#13667L = 3000047)]
#
# == Photon Explanation ==
# The query is fully supported by Photon.
# == Optimizer Statistics (table names per statistics state) ==
#   missing = sales_transactions
#   partial =
#   full    =
# Corrective actions: consider running the following command on all tables with missing or partial statistics
#   ANALYZE TABLE <table-name> COMPUTE STATISTICS FOR ALL COLUMNS
